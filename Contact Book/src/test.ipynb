# %% [markdown]
# **OOP Programming**
# - Contact Book need CRUD Operations
# - Create, Read, Update, Delete
# - Contact details: name, phone number, email, physical address.

# %%
class ContactBook:
    def __init__(self):
        self.contacts = {}
        self.names = []

    def create(self, name:str, email, phone_number, physical_address):
        if name not in self.names:
            self.names.append(name)

        self.contacts.setdefault(name, {"email": email,
                                      "phone number": phone_number,
                                      "physical address": physical_address}
        )
        print("New Contact created.")

    def show(self):
            for name in self.names:
                print(name)
                print(f"    Email: {self.contacts[name]['email']}")
                print(f"    Phone Number: {self.contacts[name]['phone number']}")
                print(f"    Physical Address: {self.contacts[name]['physical address']}")
                print("---------------------------------")

    def edit(self, name, new_name, email, phone_number, physical_address):
        if name in self.names:
            if name == new_name:
                self.contacts.update({name: {"email": email,
                                        "phone number": phone_number,
                                        "physical address": physical_address}}
                )
            else:
                self.contacts.pop(name)
                self.contacts.update({new_name: {"email": email,
                                        "phone number": phone_number,
                                        "physical address": physical_address}}
                )
                self.names.remove(name)
                self.names.append(new_name)
                
            print(f"{name}'s Contact Edited.")
        else:
            print("This contact doesn't exist.")

    def delete(self, name):
        if name in self.names:
            self.contacts.pop(name)
            self.names.remove(name)
            print("Contact Deleted.")
        else:
            print("This contact doesn't exist.")

    def search(self, name):
        if name in self.names:
            print(name)
            print(f"    Email: {self.contacts[name]['email']}")
            print(f"    Phone Number: {self.contacts[name]['phone number']}")
            print(f"    Physical Address: {self.contacts[name]['physical address']}")
            print("---------------------------------")
        else:
            print(f"There is no {name}")

# %%
c_book = ContactBook()

# %%
c_book.create("Erfan", "e.taherirani81@gmail.com", "09130228062", "Earth")
# Out:
# New Contact created.

# %%
c_book.create("Pezhman Taherirani", "Pezhman@gamil.com", "09131948062", "Isfahan")
# Out:
# New Contact created.

# %%
c_book.show()
# Out:
# Erfan
#     Email: e.taherirani81@gmail.com
#     Phone Number: 09130228062
#     Physical Address: Earth
# ---------------------------------
# Pezhman Taherirani
#     Email: Pezhman@gamil.com
#     Phone Number: 09131948062
#     Physical Address: Isfahan
# ---------------------------------

# %%
c_book.names
# Out:
# ['Erfan', 'Pezhman Taherirani']

# %%
c_book.edit('Erfan','Erfan' , 'E', "09130228062", "Earth")
# Out:
# Erfan's Contact Edited.

# %%
c_book.delete('Erfan')
# Out:
# Contact Deleted.

# %%
c_book.search('Pezhman Taherirani')
# Out:
# Pezhman Taherirani
#     Email: Pezhman@gamil.com
#     Phone Number: 09131948062
#     Physical Address: Isfahan
# ---------------------------------
